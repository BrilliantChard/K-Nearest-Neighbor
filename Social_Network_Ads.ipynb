# %% [markdown]
# <a href="https://colab.research.google.com/github/BrilliantChard/K-Nearest-Neighbor/blob/main/Social_Network_Ads.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Social_Network_Ads.csv')
data.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
data.isnull().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB

# %%
data.columns
# Out:
# Index(['User ID', 'Gender', 'Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %%
data['Purchased'].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
gender = pd.get_dummies(data['Gender'], drop_first=True)
data = pd.concat([data, gender], axis=1)

# %%
data.drop(['Gender'], axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['User ID', 'Age', 'EstimatedSalary', 'Purchased', 'Male'], dtype='object')

# %%
x = data[['Age', 'EstimatedSalary', 'Male']]
y = data['Purchased']

# %%
from sklearn.preprocessing import  StandardScaler
scaler = StandardScaler()
scaler.fit(x)
# Out:
# StandardScaler()

# %%
scaled_features = scaler.transform(x)
scaled_features
# Out:
# array([[-1.78179743, -1.49004624,  1.02020406],
#        [-0.25358736, -1.46068138,  1.02020406],
#        [-1.11320552, -0.78528968, -0.98019606],
#        ...,
#        [ 1.17910958, -1.46068138, -0.98019606],
#        [-0.15807423, -1.07893824,  1.02020406],
#        [ 1.08359645, -0.99084367, -0.98019606]])

# %% [markdown]
# # *Creating a DataFrame from Features*

# %%
data_features = pd.DataFrame(scaled_features, columns=x.columns)
data_features.head()
# Out:
#         Age  EstimatedSalary      Male
# 0 -1.781797        -1.490046  1.020204
# 1 -0.253587        -1.460681  1.020204
# 2 -1.113206        -0.785290 -0.980196
# 3 -1.017692        -0.374182 -0.980196
# 4 -1.781797         0.183751  1.020204

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(scaled_features, y, test_size=0.2, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
pred = knn.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
confusion_matrix(y_test, pred)
# Out:
# array([[50,  2],
#        [ 7, 21]])

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92        52
#            1       0.91      0.75      0.82        28
#
#     accuracy                           0.89        80
#    macro avg       0.90      0.86      0.87        80
# weighted avg       0.89      0.89      0.88        80
